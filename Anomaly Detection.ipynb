# %% [markdown]
# # Anomally Detection

# %% [markdown]
# ## Specifying the question
#
# Part 4: Anomaly Detection
#
# Check whether there are any anomalies in the given sales dataset. The objective of this task being fraud detection. Data to use is http://bit.ly/CarreFourSalesDataset

# %%
# Installing anomalize package
# ---
# 
install.packages("anomalize")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
# Load tidyverse and anomalize
# ---
# 
library(tidyverse)
library(anomalize)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.0     ✔ purrr   0.3.3
# ✔ tibble  2.1.3     ✔ dplyr   0.8.5
# ✔ tidyr   1.0.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# ══ Use anomalize to improve your Forecasts by 50%! ═════════════════════════════
# Business Science offers a 1-hour course - Lab #18: Time Series Anomaly Detection!
# </> Learn more at: https://university.business-science.io/p/learning-labs-pro </>

# %%
# loading our dataset

df = read.csv('Supermarket_Sales_Forecasting - Sales.csv')
head(df)
# Out:
#   Date      Sales
# 1 1/5/2019  548.9715
# 2 3/8/2019   80.2200
# 3 3/3/2019  340.5255
# 4 1/27/2019 489.0480
# 5 2/8/2019  634.3785
# 6 3/25/2019 627.6165

# %%
# Collect our time series data
# ---
# 
tidyverse_cran_downloads
# Out:
# Error in parse(text = x, srcfile = src): attempt to use zero-length variable name
# Traceback:

# %%
logs_path <- "Supermarket_Sales_Forecasting - Sales.csv"

install.packages("tibbletime")
library(tibbletime)
# Grouping by server and converting to tibbletime
security_access_logs <- read_csv(logs_path) %>%
  group_by(Sales) %>%
  as_tbl_time(Date)

security_access_logs
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Parsed with column specification:
# cols(
#   Date = col_character(),
#   Sales = col_double()
# )
# Error: Specified `index` is not time based
# Traceback:
#
# 1. read_csv(logs_path) %>% group_by(Sales) %>% as_tbl_time(Date)
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)
# 9. as_tbl_time(., Date)
# 10. as_tbl_time.tbl_df(., Date)
# 11. tbl_time(x, !!index_quo)
# 12. validate_tbl_time(new_tbl_time(x, index_quo = index_quo, index_time_zone = index_time_zone,
#   .     subclass = subclass))
# 13. assert_index_class_is_allowed(x)
# 14. assertthat::assert_that(inherits_allowed_datetime(index_col),
#   .     msg = "Specified `index` is not time based")

# %%
tidyverse_cran_downloads %>%
    time_decompose(count) %>%
    anomalize(remainder) %>%
    time_recompose() %>%
    plot_anomalies(time_recomposed = TRUE, ncol = 3, alpha_dots = 0.5)
# Out:
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
# plot without title
